# %% [markdown]
# # Matplotlib Comprehensive Practice Notebook: 100 Questions
# ### Master Data Visualization using `netflix_titles.csv` and `IPL_Status_2024.csv`
#
# This notebook contains 100 carefully crafted visualization challenges divided into **Easy**, **Medium**, and **Hard** levels to help you master every possible concept of Matplotlib.
#
# #### Covered Plot Types:
# 1. 2D Line Plot
# 2. Scatter Plot
# 3. Histogram
# 4. Bar Chart
# 5. Pie Chart
# 6. Coloured Scatter Chart
# 7. Annotations
# 8. 3D Line Plot
# 9. 3D Scatter Plot
# 10. Surface Plot
# 11. Contour Plot
#
# ---

# %% [markdown]
# ## Setup and Data Loading
# Run the following cell to import required libraries and load the datasets.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Load datasets
ipl = pd.read_csv('/Users/harshitkumarprajapat/Desktop/ML/CampusX/100-Matplotlib-Problems/Data/IPL_Status_2024.csv')
netflix = pd.read_csv('/Users/harshitkumarprajapat/Desktop/ML/CampusX/100-Matplotlib-Problems/Data/netflix_titles.csv')

print("Datasets loaded successfully!")
# Out:
# Datasets loaded successfully!

# %% [markdown]
# ### Question 1 [Easy - 2D Line Plot]
# Plot a simple line chart showing the total Runs scored by the top 10 players in IPL 2024 (ordered by POS). Add an appropriate title and axis labels.
#
# ```python
# # Write your code below
# ```

# %%
top = ipl.sort_values('POS').head(10)
plt.plot(top['Player'],top['Runs'])
plt.xticks(rotation=90)
plt.title('Analysis')
plt.xlabel('Players')
plt.ylabel('Runs')
plt.show()

# %% [markdown]
# ### Question 2 [Easy - 2D Line Plot]
# Plot the trend of the total number of content titles (Movies and TV Shows combined) released per year on Netflix between 2010 and 2021.
#
# ```python
# # Write your code below
# ```

# %%
# Filter years 2010–2021 and count titles per year
netflix_total = netflix[
    (netflix['release_year'] >= 2010) &
    (netflix['release_year'] <= 2021)
]['release_year'].value_counts().sort_index()

# Line Plot
plt.figure(figsize=(10,5))
plt.plot(netflix_total.index, netflix_total.values, marker='o')

plt.title('Total Netflix Content Released per Year (2010-2021)')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.xticks(netflix_total.index, rotation=45)
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Question 3 [Easy - 2D Line Plot]
# Create a line plot showing the cumulative sum of Runs scored by the top 15 players in the IPL 2024 dataset.
#
# ```python
# # Write your code below
# ```

# %%
top15 = ipl.sort_values('Runs', ascending=False).head(15)
top15['cum_runs'] = top15['Runs'].cumsum()
top15[['Player', 'Runs', 'cum_runs']]

plt.plot(top15['Player'],top15['cum_runs'],marker='o')
plt.xlabel('Players')
plt.ylabel('Cumulative Runs')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Question 4 [Easy - 2D Line Plot]
# Plot the number of TV Shows added to Netflix over the years using a green dashed line style with dot markers.
#
# ```python
# # Write your code below
# ```

# %%
plt.style.use('fivethirtyeight')
tvshow=netflix[netflix['type']=='TV Show'].groupby('release_year').size()

plt.figure(figsize=(25,7))
plt.plot(tvshow.index,tvshow.values,linestyle='dashed',marker='o',color='green',markersize=10)
plt.xticks(range(tvshow.index.min(), tvshow.index.max() + 1),rotation=90)
plt.title('Number of TV show per year')
plt.xlabel('Years')
plt.ylabel('Number of shows')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Question 5 [Easy - Scatter Plot]
# Create a basic scatter plot of Runs (y-axis) vs Balls Faced (BF) (x-axis) for all players in IPL 2024.
#
# ```python
# # Write your code below
# ```

# %%
plt.scatter(ipl['Runs'],ipl['BF'])

# %% [markdown]
# ### Question 6 [Easy - Scatter Plot]
# Plot a scatter plot showing the relationship between Average (Avg) and Strike Rate (SR) for players who scored more than 200 runs.
#
# ```python
# # Write your code below
# ```

# %%
two_h = ipl.loc[ipl['Runs']>200]
plt.scatter(two_h['Avg'],two_h['SR'],label='Players')
plt.xlabel('Average')
plt.ylabel('Strike Rate')
plt.legend()
plt.show()

# %% [markdown]
# ### Question 7 [Easy - Scatter Plot]
# Generate a scatter plot showing the release_year of Netflix movies vs an arbitrary row index for the first 500 rows to see data spread.
#
# ```python
# # Write your code below
# ```

# %%
movies = netflix.head(500)
plt.figure(figsize=(10, 5))
plt.scatter( movies.index,movies['release_year'])

plt.title('Netflix Release Year Distribution (First 500 Rows)')
plt.xlabel('Row Index')
plt.ylabel('Release Year')
plt.show()

# %% [markdown]
# ### Question 8 [Easy - Histogram]
# Plot a basic histogram showing the distribution of Runs scored by all players in IPL 2024 with 10 bins.
#
# ```python
# # Write your code below
# ```

# %%
plt.hist(ipl['Runs'],bins=10)
plt.title('Distribution of Runs Scored by IPL 2024 Players')

plt.xlabel('Runs')

plt.ylabel('Number of Players')

plt.grid(True)

plt.show()

# %% [markdown]
# ### Question 9 [Easy - Histogram]
# Create a histogram of the Strike Rate (SR) of all IPL 2024 players using 20 bins and a blue color fill.
#
# ```python
# # Write your code below
# ```

# %%
plt.hist(ipl['Avg'],bins=20,color='blue')
plt.xlabel('Average')
plt.ylabel('Number of players')
plt.show()

# %% [markdown]
# ### Question 10 [Easy - Histogram]
# Plot the distribution of the release years of all contents on Netflix using a histogram.
#
# ```python
# # Write your code below
# ```

# %%
new=netflix['release_year'].value_counts()
new2=new.head(20)
plt.hist(new2.values,bins=[0,100,200,300,400,500,600,700,800,900,1000,1100,1200])
plt.show()

# %% [markdown]
# ### Question 11 [Easy - Histogram]
# Extract the numeric values from the 'duration' column for Movies on Netflix (e.g., '90 min' -> 90) and plot their distribution using a histogram.
#
# ```python
# # Write your code below
# ```

# %%
duration = pd.to_numeric(
    netflix[netflix['type'] == 'Movie']['duration']
    .str.extract(r'(\d+)')[0],
    errors='coerce'
)

plt.hist(duration.dropna(), bins=10)
plt.show()

# %% [markdown]
# ### Question 12 [Easy - Bar Chart]
# Create a vertical bar chart showing the number of contents (Movies vs TV Shows) available on Netflix.
#
# ```python
# # Write your code below
# ```

# %%
bar = netflix['type'].value_counts()

plt.bar(bar.index, bar.values)
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Movies vs TV Shows')
plt.show()

# %% [markdown]
# ### Question 13 [Easy - Bar Chart]
# Create a horizontal bar chart showing the top 10 countries with the most content on Netflix.
#
# ```python
# # Write your code below
# ```

# %%
top = netflix['country'].value_counts().head(10)
plt.barh(top.index,top.values)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### Question 14 [Easy - Bar Chart]
# Create a vertical bar chart showing the top 10 players with the highest number of sixes (6s) in IPL 2024.
#
# ```python
# # Write your code below
# ```

# %%
top_10 = (
    ipl.sort_values('6s', ascending=False)
       .head(10)
)

plt.figure(figsize=(10, 6))
plt.bar(top_10['Player'], top_10['6s'])

plt.title('Top 10 Players with Highest Sixes in IPL 2024')
plt.xlabel('Player')
plt.ylabel('Number of Sixes')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Question 15 [Easy - Bar Chart]
# Plot a bar chart showing the frequency of the top 5 ratings (e.g., TV-MA, TV-14) present in the Netflix dataset.
#
# ```python
# # Write your code below
# ```

# %%
rating=netflix['rating'].value_counts()
plt.bar(rating.index,rating.values)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Question 16 [Easy - Bar Chart]
# Plot a bar chart showing the number of centuries (100) scored by the top 10 run-scorers in IPL 2024.
#
# ```python
# # Write your code below
# ```

# %%
top_10=ipl.sort_values('Runs',ascending=False).head(10)
plt.bar(top_10['Player'],top_10['100'],label='100s in ipl')
plt.xlabel('Player')
plt.ylabel('100s')
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Question 17 [Easy - Pie Chart]
# Create a pie chart showing the proportion of Movies vs TV Shows in the entire Netflix dataset. Include percentages.
#
# ```python
# # Write your code below
# ```

# %%
typecount=netflix['type'].value_counts()
plt.pie(typecount,labels=['Movie','TV show'],autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ### Question 18 [Easy - Pie Chart]
# Plot a pie chart displaying the distribution of content from the top 5 countries on Netflix, grouping all other countries as 'Others'.
#
# ```python
# # Write your code below
# ```

# %%
country_counts = netflix['country'].dropna().value_counts()
top_5 = country_counts.head(5)

others = country_counts.iloc[5:].sum()

data = top_5.copy()
data['Others'] = others

plt.figure(figsize=(8, 8))
plt.pie(
    data,
    labels=data.index,
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Netflix Content Distribution by Top 5 Countries')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Question 19 [Easy - Pie Chart]
# Create a pie chart showing the share of total runs scored by the top 5 IPL players compared to the rest of the players combined.
#
# ```python
# # Write your code below
# ```

# %%
player_runs = ipl.groupby('Player')['Runs'].sum().sort_values(ascending=False)
top_5 = player_runs.head(5)
others = player_runs.iloc[5:].sum()

data = top_5.copy()
data['Others'] = others

plt.figure(figsize=(8, 8))
plt.pie(
    data,
    labels=data.index,
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Share of Total IPL Runs: Top 5 Players vs Others')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Question 20 [Easy - Pie Chart]
# Plot a pie chart for the top 4 ratings on Netflix with custom hex colors for each slice.
#
# ```python
# # Write your code below
# ```

# %%
ratings = netflix['rating'].value_counts().head(4)
colors = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA600']

plt.figure(figsize=(8, 8))
plt.pie(
    ratings,
    labels=ratings.index,
    colors=colors,
    autopct='%1.1f%%',
    startangle=90
)

plt.title('Top 4 Netflix Ratings Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Question 21 [Easy - Coloured Scatter Chart]
# Create a scatter plot of Runs vs Balls Faced (BF) for IPL players, where the markers are colored based on the number of matches played (Mat).
#
# ```python
# # Write your code below
# ```

# %%
plt.scatter(ipl['Runs'],ipl['BF'],c=ipl['Mat'])
plt.colorbar()

# %% [markdown]
# ### Question 22 [Easy - Coloured Scatter Chart]
# Plot a scatter chart of Average (Avg) vs Strike Rate (SR) for IPL players, coloring the points based on the number of sixes (6s) hit.
#
# ```python
# # Write your code below
# ```

# %%
plt.scatter(ipl['Avg'],ipl['SR'],c=ipl['6s'])
plt.colorbar()

# %% [markdown]
# ### Question 23 [Easy - Coloured Scatter Chart]
# Create a scatter plot of Netflix Release Year vs Title Length (number of characters), colored by whether it is a Movie or TV Show (map to 0 and 1).
#
# ```python
# # Write your code below
# ```

# %%
length = []
netflix_edit=netflix.copy()
netflix_edit['number']=netflix['type'].replace({'Movie':1,'TV Show':2})
for i in netflix['title']:
    length.append(len(i))
plt.figure(figsize=(15,7))
plt.scatter(netflix['release_year'],length, c = netflix_edit['number'])
plt.colorbar()

# %% [markdown]
# ### Question 24 [Easy - Annotations]
# Create a line plot of the top 10 IPL run-scorers and use a simple text annotation to mark Virat Kohli's point as 'Orange Cap Winner'.
#
# ```python
# # Write your code below
# ```

# %%
top_10=ipl.sort_values('Runs',ascending=False).head(10)
top_10
plt.plot(top_10['Player'],top_10['Runs'])
plt.text('Virat Kohli RCB',741,'Orange Cap Winner',fontdict={'color':'orange'})
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Question 25 [Easy - Annotations]
# Plot a scatter chart of Runs vs SR and annotate the point with the highest Strike Rate with the text 'Max SR'.
#
# ```python
# # Write your code below
# ```

# %%
plt.scatter(ipl['Runs'],ipl['SR'])
plt.text(9,300,'Highest SR')
# ipl.sort_values('SR',ascending=False).head()
# Out:
# Text(9, 300, 'Highest SR')

# %% [markdown]
# ### Question 26 [Easy - Annotations]
# Plot the trend of Netflix content added over the years, and annotate the year 2018 with the text 'Content Boom'.
#
# ```python
# # Write your code below
# ```

# %%
boom = netflix['release_year'].value_counts()
plt.figure(figsize=(15,7))
plt.bar(boom.index,boom.values)
plt.text(2018,1147,'Boom of content')
# Out:
# Text(2018, 1147, 'Boom of content')

# %% [markdown]
# ### Question 27 [Easy - 3D Line Plot]
# Create a basic 3D line plot using the POS, Runs, and Strike Rate (SR) of the top 30 players in the IPL dataset.
#
# ```python
# # Write your code below
# ```

# %%
top30=ipl.head(30)
plt.figure()
ax = plt.subplot(projection='3d')
ax.plot3D(top30['POS'],top30['Runs'],top30['SR'])

# %% [markdown]
# ### Question 28 [Easy - 3D Line Plot]
# Plot a 3D line showing a sequence of points for the top 20 players using Matches (Mat), Innings (Inns), and Runs as axes.
#
# ```python
# # Write your code below
# ```

# %%
top20 = ipl.sort_values('Runs', ascending=False).head(20)

fig = plt.figure(figsize=(12,8))

ax = plt.subplot(projection='3d')

ax.plot(top20['Mat'],top20['Inns'],top20['Runs'],marker='o')

# %% [markdown]
# ### Question 29 [Easy - 3D Scatter Plot]
# Create a basic 3D scatter plot showing Runs, Balls Faced (BF), and Average (Avg) for all players in IPL 2024.
#
# ```python
# # Write your code below
# ```

# %%
fig = plt.figure()
ax = plt.subplot(projection='3d')
ax.scatter3D(ipl['Runs'],ipl['BF'],ipl['Avg'])

# %% [markdown]
# ### Question 30 [Easy - 3D Scatter Plot]
# Create a 3D scatter plot using Netflix data with Release Year on X, Movie Duration (numeric minutes) on Y, and Title Length on Z.
#
# ```python
# # Write your code below
# ```

# %%
movies = netflix[netflix['type'] == 'Movie']
duration = pd.to_numeric(movies['duration'].str.extract(r'(\d+)')[0],errors='coerce')
length =[]
for i in movies['title']:
    length.append(len(i))

fig=plt.figure()
ax = plt.subplot(projection='3d')
ax.scatter3D(movies['release_year'],duration.values,length)

# %% [markdown]
# ### Question 31 [Easy - Surface Plot]
# Generate a 3D grid using np.meshgrid based on the range of IPL player matches (1 to 16) and innings (1 to 16), and plot a dummy mathematical surface $Z = X^2 + Y^2$ over it.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 32 [Easy - Surface Plot]
# Create a 3D surface plot of $Z = \sin(\sqrt{X^2 + Y^2})$ where X and Y are generated on a grid from -5 to 5, using a standard colormap.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 33 [Easy - Contour Plot]
# Create a 2D contour line plot for the function $Z = X^2 - Y^2$ using a meshgrid of size 20x20 spanning from -3 to 3.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 34 [Easy - Contour Plot]
# Create a filled contour plot (`contourf`) for $Z = \sin(X) \cdot \cos(Y)$ on a 2D grid representing a 10x10 space.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 35 [Easy - Contour Plot]
# Plot a basic contour chart showing 5 level lines for a custom function $Z = X \cdot Y$ where X is bounded by minimum and maximum IPL Runs, and Y by Average.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 36 [Medium - 2D Line Plot]
# Plot two separate line lines on the same chart: one for the number of Movies released per year and another for TV Shows released per year on Netflix from 2005 to 2021. Use distinct colors, markers, and include a legend.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 37 [Medium - 2D Line Plot]
# Plot the trend of the average Strike Rate of IPL players grouped by their position (POS) using a customized line width, circular markers, and gridlines enabled.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 38 [Medium - 2D Line Plot]
# Create a multi-line plot displaying both 'Matches' (Mat) and 'Inns' (Inns) for the top 20 IPL players on the same x-axis, using a secondary y-axis (`twinx()`) for one of the metrics.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 39 [Medium - Scatter Plot]
# Create a scatter plot of Runs vs Average for IPL players where the size of each marker dynamically represents the number of fours (4s) hit by that player.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 40 [Medium - Scatter Plot]
# Plot a scatter chart showing Netflix Release Year vs Movie Duration (in minutes) with an alpha transparency of 0.4 to visualize dense overlapping regions clearly.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 41 [Medium - Scatter Plot]
# Create a scatter plot of Strike Rate vs Average for players with more than 10 matches, changing the marker style (e.g., 'o' vs 'x') based on whether they have scored at least one century (100 > 0).
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 42 [Medium - Histogram]
# Plot a dual-histogram on the same chart comparing the distribution of Runs scored by IPL players with an Average > 30 vs players with an Average <= 30. Use semi-transparent overlapping bars.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 43 [Medium - Histogram]
# Create a cumulative histogram of the release years of all Netflix TV Shows, showing the growth of content over time.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 44 [Medium - Histogram]
# Plot a histogram of IPL player Strike Rates and superimpose a red theoretical normal distribution line or a kernel density curve over it.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 45 [Medium - Bar Chart]
# Create a stacked bar chart showing the number of fours (4s) and sixes (6s) hit by the top 10 run-scorers in IPL 2024. Include a clear legend and stacked colors.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 46 [Medium - Bar Chart]
# Plot a grouped bar chart showing the count of Movies vs TV Shows side-by-side for the top 5 content-producing countries on Netflix.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 47 [Medium - Bar Chart]
# Create a percentage stacked bar chart showing the proportion of Movies and TV Shows across the top 5 ratings (TV-MA, TV-14, TV-PG, R, PG-13) on Netflix.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 48 [Medium - Bar Chart]
# Extract the team acronym from the 'Player' column (e.g., 'RCB', 'CSK', 'MI') in the IPL dataset, and plot a bar chart showing the average runs scored by players of each team.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 49 [Medium - Pie Chart]
# Create a pie chart for the top 5 ratings on Netflix, applying an 'explode' effect to the largest slice, and formatting percentages to exactly two decimal places.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 50 [Medium - Pie Chart]
# Plot a donut chart (a pie chart with a white circle in the center) showing the proportion of IPL players who have scored at least one fifty (50 > 0).
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 51 [Medium - Pie Chart]
# Create a nested (double-ring) pie chart showing the global proportion of Movies vs TV Shows in the inner ring, and the breakdown of the top 2 ratings for each type in the outer ring.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 52 [Medium - Coloured Scatter Chart]
# Create a scatter plot of Runs vs Strike Rate for all IPL players. Color the markers using the 'plasma' colormap based on their Average (Avg), and attach a vertical colorbar with a specific title.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 53 [Medium - Coloured Scatter Chart]
# Plot Netflix Movie duration vs Release Year, coloring points by their rating category using a discrete color map for categories: 'PG-13', 'R', 'TV-MA', 'TV-14'.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 54 [Medium - Coloured Scatter Chart]
# Create a scatter plot of Balls Faced (BF) vs Runs in IPL, coloring points by the number of Matches (Mat) played, using a log-scaled color mapping (`matplotlib.colors.LogNorm`).
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 55 [Medium - Annotations]
# Create a scatter plot of IPL Average vs Strike Rate, and annotate the top 3 players with arrows (`arrowprops`) pointing exactly to their coordinates, with text labels showing their names inside a colored box.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 56 [Medium - Annotations]
# Create a line chart showing Netflix content additions over the years, and add a bounded box (`bbox`) annotation with text indicating the impact of the COVID-19 pandemic in 2020.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 57 [Medium - Annotations]
# Draw a vertical bar chart of the top 10 run-scorers in IPL and programmatically annotate each bar with its exact value centered on top of the bar.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 58 [Medium - 3D Line Plot]
# Plot a 3D line chart connecting the coordinates of (Matches, Innings, Runs) for the top 30 IPL players, styling the line with a color gradient or distinct marker points.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 59 [Medium - 3D Line Plot]
# Create a 3D line plot showing the trajectory of cumulative runs, cumulative balls faced, and player index for the top 40 players in the IPL dataset.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 60 [Medium - 3D Scatter Plot]
# Create a 3D scatter plot of Runs, Strike Rate, and Average where the color of each point is determined by the number of sixes (6s) and the size by the number of matches played.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 61 [Medium - 3D Scatter Plot]
# Create a 3D scatter plot of Netflix shows using Release Year, Duration (numeric minutes), and Title Length, using different markers (e.g., 'o' for Movies and '^' for TV Shows).
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 62 [Medium - Surface Plot]
# Create a 3D surface plot using a bivariate distribution grid to model the relationship between player Runs and Strike Rate, utilizing the 'coolwarm' colormap with shadows enabled.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 63 [Medium - Surface Plot]
# Generate a 3D surface plot from a 2D matrix representing a pivot table or binned average of runs across different combinations of Matches and Innings.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 64 [Medium - Surface Plot]
# Plot a 3D surface of $Z = \cos(\sqrt{X^2 + Y^2})$ over a grid representing normalized Average and Strike Rate ranges from the IPL dataset.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 65 [Medium - Contour Plot]
# Create a filled contour plot (`contourf`) showing a density approximation of IPL players' performance (Runs vs SR), with 15 custom level lines and an attached colorbar.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 66 [Medium - Contour Plot]
# Plot a contour chart showing the iso-lines of a performance index calculated as $\text{Score} = \text{Avg} \times \text{SR}$, evaluated on a regular grid of Avg (10 to 60) and SR (100 to 200). Label the lines using `clabel`.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 67 [Medium - Contour Plot]
# Create a multi-panel figure containing a 3D Surface plot on the left subplot and its corresponding 2D Contour plot on the right subplot using `plt.subplot(1, 2, ...)`.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 68 [Hard - 2D Line Plot]
# Using GridSpec, create a 3-panel layout: a main line chart showing the trend of average movie durations on Netflix from 2000 to 2021, and two smaller subplots showing the distribution of durations for specific genres (e.g., 'Dramas' vs 'Comedies').
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 69 [Hard - 2D Line Plot]
# Plot the running average (moving average) of Strike Rates of IPL players across their positions. Fill the area between the running average and the actual values using `plt.fill_between` with a light color and 0.3 alpha transparency.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 70 [Hard - 2D Line Plot]
# Create a highly customized line plot showing the growth rate (percentage change year-over-year) of Netflix content additions. Use a custom font, specialized gridlines, and path effects (`patheffects.withStroke`) to make the line pop.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 71 [Hard - Scatter Plot]
# Plot an advanced scatter plot comparing IPL Runs vs Balls Faced. Add a marginal box plot or histogram for both variables on the top and right sides of the scatter plot using a custom multi-axis arrangement.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 72 [Hard - Scatter Plot]
# Analyze the 'listed_in' column in Netflix to find the top 3 most common genres. Create a scatter plot of Release Year vs Content Duration for these genres, utilizing unique markers and a multi-level custom legend with manually specified handles.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 73 [Hard - Scatter Plot]
# Create a scatter plot of IPL Strike Rate vs Average. Draw an elliptical bounding patch or a shaded circle centered at the mean values that highlights the 'sweet spot' (players with Avg > 40 and SR > 140) using `matplotlib.patches`.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 74 [Hard - Histogram]
# Create a multi-layered overlapping histogram showing the distribution of movie durations on Netflix for three different countries: 'United States', 'India', and 'United Kingdom'. Apply a different step type (`histtype='step'`) and line width for each to maintain readability.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 75 [Hard - Histogram]
# Plot a histogram of IPL player runs where the color of each individual bin bar changes dynamically according to its height (frequency count), utilizing a colormap and normalization over the bin counts.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 76 [Hard - Histogram]
# Create a 2D histogram (`hist2d`) or a hexbin plot (`hexbin`) showing the joint distribution of Runs and Strike Rates for all IPL players. Customize the grid size and add a log-scaled colorbar.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 77 [Hard - Bar Chart]
# Extract and explode all individual genres from the 'listed_in' column of Netflix. Find the top 15 genres and create a horizontal bar chart where the bars are sorted in descending order, styled with a custom gradient color palette, and each bar is explicitly labeled with its percentage contribution to the total.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 78 [Hard - Bar Chart]
# Create a bidirectional (back-to-back) bar chart comparing the distribution of content ratings between the United States and India on Netflix (e.g., X-axis extends left for US and right for India).
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 79 [Hard - Bar Chart]
# Plot a grouped bar chart with error bars representing the standard deviation of Runs scored by players belonging to different binned groups of Strike Rates (e.g., low, medium, high SR cohorts).
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 80 [Hard - Pie Chart]
# Create a highly customized donut chart of Netflix content types. Inside the center hole, programmatically place text indicating the total count of all titles, using a large bold font, and draw radial lines from the percentage labels to the corresponding slices.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 81 [Hard - Pie Chart]
# Create a semi-circular pie chart (angle from 0 to 180 degrees) visualizing the share of boundaries (4s vs 6s) scored by the top 5 IPL teams. Use precise label positioning and formatting.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 82 [Hard - Coloured Scatter Chart]
# Create a scatter plot of IPL Runs vs Strike Rate. Use a custom divergent colormap (`TwoSlopeNorm`) centered around an Average of 30, so that players with an average below 30 are shaded in shades of red, and players above 30 are shaded in shades of blue.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 83 [Hard - Coloured Scatter Chart]
# Plot Netflix content additions by mapping the exact date added to ordinal values. Create a scatter plot of Date Added vs Release Year, coloring points by the number of words in the description, using a custom colorbar with discrete ticks and custom string labels.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 84 [Hard - Annotations]
# Create a scatter plot of IPL Runs vs Strike Rate and add an annotation that uses custom coordinate systems (`xycoords='data'`, `textcoords='offset points'`) with a fancy arrow style (`arrowstyle='->,head_width=0.5,head_length=0.5'`) and a round bounding box (`boxstyle='round,pad=0.5'`).
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 85 [Hard - Annotations]
# On a histogram of Netflix release years, dynamically compute and plot the median and mean lines, then annotate both lines with text labels placed exactly 2% above the maximum bin height using a mix of data and axes coordinate systems.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 86 [Hard - Annotations]
# Create a complex 2x2 subplot figure. Add a global text annotation or watermark across the entire figure canvas using figure coordinates (`fig.text`) with a semi-transparent rotated style (`alpha=0.1`, `rotation=45`).
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 87 [Hard - 3D Line Plot]
# Create an intricate 3D line plot that visualizes an IPL player's career-like metric progression across the top 50 rows, mapping the lines' color dynamically using a colormap along the path length via a LineCollection or custom iteration.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 88 [Hard - 3D Line Plot]
# Plot a 3D parametric line representing a custom multi-variable metric: $\alpha \cdot \text{Runs} + \beta \cdot \text{SR}$ over matches, configuring the 3D axes view depth and clipping planes explicitly.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 89 [Hard - 3D Scatter Plot]
# Create a 3D scatter plot of IPL data, set custom viewing angles using `ax.view_init(elev=35, azim=-60)`, and customize all three axes pane colors to be semi-transparent light blue with dark gray dashed gridlines.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 90 [Hard - 3D Scatter Plot]
# Plot a 3D scatter plot of Netflix content where the Z-axis represents the time gap in years between the `release_year` and the year the content was added to Netflix. Color the markers by rating and size them by description word count.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 91 [Hard - Surface Plot]
# Estimate a 2D Kernel Density Estimate (KDE) or a smoothed 2D histogram of IPL player Average and Strike Rate, and plot this density as a 3D Surface with custom lighting effects (`LightSource` from `matplotlib.colors`).
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 92 [Hard - Surface Plot]
# Create a 3D surface plot of a customized polynomial regression surface fitting Runs as a function of Matches and Innings. Overlay the actual data points as a 3D scatter plot on top of the surface.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 93 [Hard - Surface Plot]
# Plot a 3D wireframe chart (`plot_wireframe`) alongside a 3D surface chart to compare the visualization of a grid of average strike rate across different segments of data, synchronizing their camera angles.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 94 [Hard - Contour Plot]
# Create a contour plot overlaying actual data points. The contour should represent a 2D Gaussian blend of the players' positions, and the actual players should be plotted as a scatter plot on top of it.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 95 [Hard - Contour Plot]
# Use `clabel` to add inline labels to a contour plot of player performance with specific font sizes, custom formatting strings, and inline clipping enabled so lines do not cross the text.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 96 [Hard - Contour Plot]
# Set custom non-linear levels for a filled contour plot to highlight specific thresholds of a calculated productivity index ($\text{Runs} / \text{BF} \times \text{Avg}$). Color each interval with a specific manual list of hex colors.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 97 [Hard - Mixed / Advanced]
# Create an advanced multi-plot visualization using `plt.subplot2grid` that combines a 3D Scatter Plot of IPL players, a 2D Contour Plot of their density, and a horizontal Bar Chart of the top 5 run-scorers, sharing styled themes.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 98 [Hard - Mixed / Advanced]
# Implement a custom style sheet context using `with plt.style.context('dark_background'):` and generate a high-contrast coloured scatter chart of Netflix content with neon-colored annotations pointing to outliers.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 99 [Hard - Mixed / Advanced]
# Build a visual dashboard of Netflix data for a single country (e.g., 'India') containing a Pie chart of types, a Line plot of releases over years, a Histogram of movie lengths, and a customized annotation summarizing key statistics in a separate text pane.
#
# ```python
# # Write your code below
# ```

# %% [markdown]
# ### Question 100 [Hard - Mixed / Advanced]
# Write a complete script using Matplotlib's object-oriented API (`fig, ax = plt.subplots()`) to plot a 3D Surface plot of an analytical model of batsman efficiency. Customize the colorbar ticks, axes tick labels formatting, labels padding, and save the figure as a high-resolution PDF file with tight bounding box bounding.
#
# ```python
# # Write your code below
# ```
